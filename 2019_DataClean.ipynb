# %%
import pandas as pd
import os, glob

# %%
# Merging csv files (without repeating header)
data_files = glob.glob("data/*.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in data_files), ignore_index= True)
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1                280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2               2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3               2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4                139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...              ...                       ...                       ...
# 809889           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 809890           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 809891           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 809892           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 809893           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#         start station id start station name  start station latitude  \
# ...

# %%
df.count()
# Out:
# tripduration               809894
# starttime                  809894
# stoptime                   809894
# start station id           809894
# start station name         809894
# start station latitude     809894
# start station longitude    809894
# end station id             809894
# end station name           809894
# end station latitude       809894
# end station longitude      809894
# bikeid                     809894
# usertype                   809894
# birth year                 809894
# gender                     809894
# Unnamed: 0                 404947
# dtype: int64

# %%
# Export file as a CSV
df.to_csv("data/2019-citibike-tripdata.csv")
